# %%
import pandas as pd

# %%
charts = pd.read_csv("../data/billboard_charts.csv", parse_dates=["date"])
ufos = pd.read_csv("../data/nuforc_reports.csv")

# %%
pd.to_datetime("20/01/22")
# Out:
# Timestamp('2022-01-20 00:00:00')

# %%
pd.to_datetime("10.11.12", dayfirst=True, yearfirst=True)
# Out:
# Timestamp('2010-12-11 00:00:00')

# %%
meetings = ["10.11.12 Meeting","11.12.10 Meeting","09.08.07 Meeting"]
pd.to_datetime(meetings, format="%y.%m.%d Meeting")
# Out:
# DatetimeIndex(['2010-11-12', '2011-12-10', '2009-08-07'], dtype='datetime64[ns]', freq=None)

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# ...

# %%
ufos["date_time"] = pd.to_datetime(ufos["date_time"])

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 8.1+ MB

# %%
ufos["date_time"].dt.year.value_counts().head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
ufos.date_time.dt.hour.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
ufos[ufos["date_time"] < "1980"].sort_values("duration", ascending=False)
# Out:
#                                                  summary          city state  \
# 78289  Gaseous ball of pink light turquoise blue gase...      Placitas    NM
# 78957  It was round with colored lights all around it...    Fort Payne    AL
# 62511    5 disk glowing red heading west towards N.Y.C..     Levittown    NY
# 74536  Huge, sparking edged Black Sphere viewed near ...      Inyokern    CA
# 45765  My body was scanned by a beam from a small fly...   Springfield    LA
# ...                                                  ...           ...   ...
# 81494                                       MADAR REPORT  Mount Vernon    IN
# 81647  The four of us were have a meditation and spir...   North Miami    FL
# 83219  There was more than just one witness that seen...       Ketchum    OK
# 83953  Famous Coyne helicopter encounter.  ((NUFORC N...     Mansfield    OH
# 84652  I saw what I bleave to be a UFO. up close. 30f...  Indianapolis    IN
#
# ...

# %%
ufos[ufos["date_time"].dt.hour == 18]
# Out:
#                                                  summary             city  \
# 0      My wife was driving southeast on a fairly popu...          Chester
# 1      I think that I may caught a UFO on the NBC Nig...       Rocky Hill
# 4      In Peoria Arizona, I saw a cigar shaped craft ...           Peoria
# 22     A white saucer shaped entity was captured on s...      Springfield
# 67               huge orange circular fireball in Quebec    Les Escoumins
# ...                                                  ...              ...
# 88029  A long string of lights moving very slowly acr...           Tucson
# 88039  Before sunset,in the sky we saw a tear drop sh...  Ranchos de Taos
# 88082  I was cooking on the grill on my back porch. A...              NaN
# 88100  Long duration, dash-like appearance, intermitt...        Escondido
# 88101  dark object moving very straight, high and fas...         Brampton
#
#       state           date_time     shape       duration  \
# ...

# %%
ufos[ufos["date_time"].between("1993", "2008")]
# Out:
#                                                  summary  \
# 14     Bright Circle of Light followed me from Oskalo...
# 28     They were both boomerang shaped and were doing...
# 29     ((HOAX))  A fleet of ships landed in my back g...
# 30         Planes guided into the Trade Centers by UFOs.
# 152                           My diesel engine saved me?
# ...                                                  ...
# 87215  Turquoise triangle hovering then  zig zags at ...
# 87216                  Small orange orb hovering in lawn
# 87217          Monolith in front of the almost full moon
# 87940      Large disc with extremely bright white lights
# 87949  1 flickering light hovered above sky lights fo...
#
#                               city state           date_time      shape  \
# 14                     Centerville    IA 1999-08-15 02:30:00     circle
# 28                        Franklin    TN 2006-03-22 21:07:00    chevron
# ...

# %%
recent_sightings = ufos[ufos["date_time"].dt.year > 2018]

# %%
recent_sightings["date_time"].dt.date.value_counts()
# Out:
# 2019-11-11    77
# 2019-05-25    69
# 2019-05-26    67
# 2019-05-24    60
# 2019-07-04    57
#               ..
# 2019-02-27     3
# 2019-01-17     3
# 2019-03-08     2
# 2019-12-29     1
# 2019-05-09     1
# Name: date_time, Length: 357, dtype: int64

# %%
ufos['posted'] = pd.to_datetime(ufos["posted"])

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](2), float64(2), object(8)
# memory usage: 8.1+ MB

# %%
ufos['time_before_reporting'] = ufos['posted'] - ufos['date_time']

# %%
ufos['time_before_reporting'].nlargest(1).dt.days / 365
# Out:
# 86762    50.583562
# Name: time_before_reporting, dtype: float64

# %%
billboard = pd.read_csv("../data/billboard_charts.csv", parse_dates=['date'])

# %%
billboard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  datetime64[ns]
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 17.6+ MB

# %%
billboard['artist'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
number_1s = billboard['rank'] == 1
billboard[number_1s]['artist'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
billboard[number_1s]['song'].value_counts()
# Out:
# Old Town Road                               19
# Despacito                                   16
# One Sweet Day                               16
# Rockstar                                    15
# I'll Make Love To You                       14
#                                             ..
# Then Came You                                1
# You Haven't Done Nothin                      1
# You Ain't Seen Nothing Yet/Free Wheelin'     1
# Whatever Gets You Thru The Night             1
# I'll Take You There                          1
# Name: song, Length: 1104, dtype: int64

# %%
old_town = charts[charts['song'] == 'Old Town Road'].set_index('date')['rank'].plot()
old_town.invert_yaxis()
