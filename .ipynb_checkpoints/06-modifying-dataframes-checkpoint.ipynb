# %%
import pandas as pd
houses = pd.read_csv("../data/kc_house_data.csv")
titanic = pd.read_csv("../data/titanic.csv")
netflix = pd.read_csv("../data/netflix_titles.csv", sep="|", index_col=0)
btc = pd.read_csv("../data/coin_Bitcoin.csv")
countries = pd.read_csv("../data/world-happiness-report-2021.csv", index_col="Country name")

# %%
# btc.drop(labels=["Sno","Symbol","Name"], axis="columns", inplace=True)
btc.drop(columns=["SNo","Symbol","Name"], inplace=True)

# %%
countries.drop(labels="Denmark", axis="index")
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries.drop(countries.index[0:3])
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Iceland                                0.059         7.670         7.438
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %%
titanic["species"] = "human"

# %%
titanic["species"]
# Out:
# 0       human
# 1       human
# 2       human
# 3       human
# 4       human
#         ...
# 1304    human
# 1305    human
# 1306    human
# 1307    human
# 1308    human
# Name: species, Length: 1309, dtype: object

# %%
houses.insert(0, "county", "King County")

# %%
houses.head(4)
# Out:
#         county          id             date     price  bedrooms  bathrooms  \
# 0  King County  7129300520  20141013T000000  221900.0         3       1.00
# 1  King County  6414100192  20141209T000000  538000.0         3       2.25
# 2  King County  5631500400  20150225T000000  180000.0         2       1.00
# 3  King County  2487200875  20141209T000000  604000.0         4       3.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# ...

# %%
titanic.drop(columns="species")
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.insert(7, "relatives", titanic["sibsp"] + titanic["parch"])

# %%
survived = titanic["survived"] == 1
titanic[survived].sort_values("relatives", ascending=False)
# Out:
#      pclass  survived                                               name  \
# 641       3         1                  Asplund, Master. Edvin Rojj Felix
# 625       3         1                    Andersson, Miss. Erna Alexandra
# 646       3         1  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 643       3         1                     Asplund, Miss. Lillian Gertrud
# 111       1         1                     Fortune, Miss. Alice Elizabeth
# ..      ...       ...                                                ...
# 597       2         1                       Williams, Mr. Charles Eugene
# 598       2         1                               Wright, Miss. Marion
# 604       3         1                        Abelseth, Miss. Karen Marie
# 605       3         1                      Abelseth, Mr. Olaus Jorgensen
# 0         1         1                      Allen, Miss. Elisabeth Walton
#
#         sex age  sibsp  parch  relatives   ticket      fare        cabin  \
# ...

# %%
solo_passengers = titanic["relatives"] == 0
titanic[solo_passengers]["pclass"].value_counts()
# Out:
# 3    472
# 1    160
# 2    158
# Name: pclass, dtype: int64

# %%
price_per_foot = houses["price"] / houses["sqft_living"]
houses["price_sqft"] = price_per_foot

# %%
houses.price_sqft
# Out:
# 0        188.050847
# 1        209.338521
# 2        233.766234
# 3        308.163265
# 4        303.571429
#             ...
# 21608    235.294118
# 21609    173.160173
# 21610    394.216667
# 21611    250.000000
# 21612    318.627451
# Name: price_sqft, Length: 21613, dtype: float64

# %%
houses.sort_values("price_sqft", ascending=False)
# Out:
#             county          id             date      price  bedrooms  \
# 19336  King County  6021500970  20150407T000000   874950.0         2
# 4013   King County   724069059  20140509T000000  2400000.0         3
# 10446  King County  1118000320  20150508T000000  3400000.0         4
# 8623   King County  6303400395  20150130T000000   325000.0         1
# 9314   King County  4389200610  20141201T000000   903000.0         2
# ...            ...         ...              ...        ...       ...
# 1385   King County  3342700465  20150123T000000   250000.0         3
# 17197  King County  5111400086  20140512T000000   110000.0         3
# 13825  King County  5637200450  20141017T000000   257000.0         5
# 3785   King County   723049156  20140523T000000   149000.0         3
# 18262  King County  2891000610  20141211T000000   148900.0         4
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  \
# ...

# %%
mapper = {"Regional indicator" : "regional_indicator", "Ladder score" : "ladder_score"}
countries.rename(columns=mapper, inplace=True )
# Out:
#               regional_indicator  ladder_score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
mapper = {"Denmark" : "denmark", "Finland":"finland"}
countries.rename(index=mapper)
